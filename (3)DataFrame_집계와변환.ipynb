# %% [markdown]
# # 🚩 DataFrame Aggregation & Reshape
# ## 주요 토픽
# 1. Grouping Columns
# 2. Multi-Index Dataframe
# 3. Aggregating Groups
# 4. Pivot Tables
# 5. Melting Dataframe
# ## 목표
# 1. Group Dataframes by one or more columns and calculate aggregate statistics by group
# 2. Learn to access multi-index dataframe and reset to return to single index
# 3. Create pivot table to summarize data
# 4. Melt wide tables of data into a long tabular form

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. 데이터프레임 집계
# ### > groupby 메서드
# - To group data, use the groupby 메서드 and specify a column to group by
#     - Grouped columns becomes the index BY DEFAULT

# %%
league = pd.read_excel('./data/premier_league_games.xlsx')
league.head()
# Out:
#      id             league_name     season        HomeTeam         AwayTeam  \
# 0  4389  England Premier League  2015/2016         Arsenal  West Ham United
# 1  4390  England Premier League  2015/2016     Bournemouth      Aston Villa
# 2  4391  England Premier League  2015/2016         Chelsea     Swansea City
# 3  4392  England Premier League  2015/2016         Everton          Watford
# 4  4393  England Premier League  2015/2016  Leicester City       Sunderland
#
#    HomeGoals  AwayGoals
# 0          0          2
# 1          0          1
# 2          2          2
# 3          2          2
# 4          4          2

# %%
# returns Series
league.groupby('HomeTeam')['HomeGoals'].mean()
# Out:
# HomeTeam
# Arsenal                 1.631579
# Aston Villa             0.736842
# Bournemouth             1.210526
# Chelsea                 1.684211
# Crystal Palace          1.000000
# Everton                 1.842105
# Leicester City          1.842105
# Liverpool               1.736842
# Manchester City         2.473684
# Manchester United       1.421053
# Newcastle United        1.684211
# Norwich City            1.368421
# Southampton             2.052632
# Stoke City              1.157895
# Sunderland              1.210526
# Swansea City            1.052632
# Tottenham Hotspur       1.842105
# Watford                 1.052632
# West Bromwich Albion    1.052632
# West Ham United         1.789474
# Name: HomeGoals, dtype: float64

# %%
# return Dataframe
league.groupby('HomeTeam')[['HomeGoals']].mean()
# Out:
#                       HomeGoals
# HomeTeam
# Arsenal                1.631579
# Aston Villa            0.736842
# Bournemouth            1.210526
# Chelsea                1.684211
# Crystal Palace         1.000000
# Everton                1.842105
# Leicester City         1.842105
# Liverpool              1.736842
# Manchester City        2.473684
# Manchester United      1.421053
# Newcastle United       1.684211
# Norwich City           1.368421
# Southampton            2.052632
# Stoke City             1.157895
# Sunderland             1.210526
# Swansea City           1.052632
# Tottenham Hotspur      1.842105
# Watford                1.052632
# West Bromwich Albion   1.052632
# West Ham United        1.789474

# %% [markdown]
# ## 2. 그룹화 - Multiple Columns
# ### > groupby 메서드
# - 리스트를 전달
# - multi-index object를 리턴
# - as_index 매개변수

# %%
league = pd.read_excel('./data/premier_league_games_full.xlsx')
league.head()
# Out:
#      id             league_name     season           HomeTeam  \
# 0  1729  England Premier League  2008/2009  Manchester United
# 1  1730  England Premier League  2008/2009            Arsenal
# 2  1731  England Premier League  2008/2009         Sunderland
# 3  1732  England Premier League  2008/2009    West Ham United
# 4  1733  England Premier League  2008/2009        Aston Villa
#
#                AwayTeam  HomeGoals  AwayGoals
# 0      Newcastle United          1          1
# 1  West Bromwich Albion          1          0
# 2             Liverpool          0          1
# 3        Wigan Athletic          2          1
# 4       Manchester City          4          2

# %%
league.groupby(['HomeTeam', 'season'])[['HomeGoals']].sum()
# Out:
#                                    HomeGoals
# HomeTeam                season
# Arsenal                 2008/2009         31
#                         2009/2010         48
#                         2010/2011         33
#                         2011/2012         39
#                         2012/2013         47
# ...                                      ...
# Wigan Athletic          2011/2012         22
#                         2012/2013         26
# Wolverhampton Wanderers 2009/2010         13
#                         2010/2011         30
#                         2011/2012         19
#
# [160 rows x 1 columns]

# %%
league.groupby(['season', 'HomeTeam'])[['HomeGoals']].sum()
# Out:
#                                 HomeGoals
# season    HomeTeam
# 2008/2009 Arsenal                      31
#           Aston Villa                  27
#           Blackburn Rovers             22
#           Bolton Wanderers             21
#           Chelsea                      33
# ...                                   ...
# 2015/2016 Swansea City                 20
#           Tottenham Hotspur            35
#           Watford                      20
#           West Bromwich Albion         20
#           West Ham United              34
#
# [160 rows x 1 columns]

# %%
(
    league
    .groupby(['season', 'HomeTeam'], as_index=False)[['HomeGoals']]
    .sum()
    .query("HomeTeam == 'Arsenal'")
)
# Out:
#         season HomeTeam  HomeGoals
# 0    2008/2009  Arsenal         31
# 20   2009/2010  Arsenal         48
# 40   2010/2011  Arsenal         33
# 60   2011/2012  Arsenal         39
# 80   2012/2013  Arsenal         47
# 100  2013/2014  Arsenal         36
# 120  2014/2015  Arsenal         41
# 140  2015/2016  Arsenal         31

# %% [markdown]
# ## 3. 데이터프레임 멀티인덱스
# - Multi-Indexes are generally created through aggregation operations
# - Multi-Indexes are stored as a list of tuples
# ### > 데이터 조회
# - loc/iloc 접근자 모두 사용 가능

# %%
agg_league = (
    league
    .groupby(['season', 'HomeTeam'])[['HomeGoals']]
    .sum()
)
agg_league.head()
# Out:
#                             HomeGoals
# season    HomeTeam
# 2008/2009 Arsenal                  31
#           Aston Villa              27
#           Blackburn Rovers         22
#           Bolton Wanderers         21
#           Chelsea                  33

# %%
agg_league.loc['2008/2009']
# Out:
#                       HomeGoals
# HomeTeam
# Arsenal                      31
# Aston Villa                  27
# Blackburn Rovers             22
# Bolton Wanderers             21
# Chelsea                      33
# Everton                      31
# Fulham                       28
# Hull City                    18
# Liverpool                    41
# Manchester City              40
# Manchester United            43
# Middlesbrough                17
# Newcastle United             24
# Portsmouth                   26
# Stoke City                   22
# Sunderland                   21
# Tottenham Hotspur            21
# West Bromwich Albion         26
# West Ham United              23
# Wigan Athletic               17

# %%
agg_league.loc['2008/2009':'2010/2011']
# Out:
#                                    HomeGoals
# season    HomeTeam
# 2008/2009 Arsenal                         31
#           Aston Villa                     27
#           Blackburn Rovers                22
#           Bolton Wanderers                21
#           Chelsea                         33
#           Everton                         31
#           Fulham                          28
#           Hull City                       18
#           Liverpool                       41
#           Manchester City                 40
#           Manchester United               43
#           Middlesbrough                   17
#           Newcastle United                24
#           Portsmouth                      26
#           Stoke City                      22
#           Sunderland                      21
#           Tottenham Hotspur               21
#           West Bromwich Albion            26
#           West Ham United                 23
#           Wigan Athletic                  17
# 2009/2010 Arsenal                         48
#           Aston Villa                     29
#           Birmingham City                 19
#           Blackburn Rovers                28
#           Bolton Wanderers                26
#           Burnley                         25
#           Chelsea                         68
#           Everton                         35
#           Fulham                          27
#           Hull City                       22
#           Liverpool                       43
#           Manchester City                 41
#           Manchester United               52
#           Portsmouth                      24
#           Stoke City                      24
#           Sunderland                      32
#           Tottenham Hotspur               40
#           West Ham United                 30
#           Wigan Athletic                  19
#           Wolverhampton Wanderers         13
# 2010/2011 Arsenal                         33
#           Aston Villa                     26
#           Birmingham City                 19
#           Blackburn Rovers                22
#           Blackpool                       30
#           Bolton Wanderers                34
#           Chelsea                         39
#           Everton                         31
#           Fulham                          30
#           Liverpool                       37
#           Manchester City                 34
#           Manchester United               49
#           Newcastle United                41
#           Stoke City                      31
#           Sunderland                      25
#           Tottenham Hotspur               30
#           West Bromwich Albion            30
#           West Ham United                 24
#           Wigan Athletic                  22
#           Wolverhampton Wanderers         30

# %%
agg_league.loc[('2008/2009', 'Arsenal')]
# Out:
# HomeGoals    31
# Name: (2008/2009, Arsenal), dtype: int64

# %%
agg_league.loc[('2008/2009', 'Arsenal'):('2008/2009', 'Bolton Wanderers')]
# Out:
#                             HomeGoals
# season    HomeTeam
# 2008/2009 Arsenal                  31
#           Aston Villa              27
#           Blackburn Rovers         22
#           Bolton Wanderers         21

# %%
agg_league.iloc[:4]
# Out:
#                             HomeGoals
# season    HomeTeam
# 2008/2009 Arsenal                  31
#           Aston Villa              27
#           Blackburn Rovers         22
#           Bolton Wanderers         21

# %%
agg_league.iloc[-1]
# Out:
# HomeGoals    34
# Name: (2015/2016, West Ham United), dtype: int64

# %% [markdown]
# ---

# %%
agg_league = (
    league
    .groupby(['season', 'HomeTeam'])
    .agg({'HomeGoals': ['sum', 'mean']})
)

agg_league.head()
# Out:
#                            HomeGoals
#                                  sum      mean
# season    HomeTeam
# 2008/2009 Arsenal                 31  1.631579
#           Aston Villa             27  1.421053
#           Blackburn Rovers        22  1.157895
#           Bolton Wanderers        21  1.105263
#           Chelsea                 33  1.736842

# %%
agg_league.iloc[0, 0]
# Out:
# 31

# %%
agg_league.iloc[1, 1]
# Out:
# 1.4210526315789473

# %%
agg_league.iloc[1, :]
# Out:
# HomeGoals  sum     27.000000
#            mean     1.421053
# Name: (2008/2009, Aston Villa), dtype: float64

# %%
agg_league.loc['2010/2011', ('HomeGoals', )]
# Out:
#                          sum      mean
# HomeTeam
# Arsenal                   33  1.736842
# Aston Villa               26  1.368421
# Birmingham City           19  1.000000
# Blackburn Rovers          22  1.157895
# Blackpool                 30  1.578947
# Bolton Wanderers          34  1.789474
# Chelsea                   39  2.052632
# Everton                   31  1.631579
# Fulham                    30  1.578947
# Liverpool                 37  1.947368
# Manchester City           34  1.789474
# Manchester United         49  2.578947
# Newcastle United          41  2.157895
# Stoke City                31  1.631579
# Sunderland                25  1.315789
# Tottenham Hotspur         30  1.578947
# West Bromwich Albion      30  1.578947
# West Ham United           24  1.263158
# Wigan Athletic            22  1.157895
# Wolverhampton Wanderers   30  1.578947

# %%
agg_league.loc['2010/2011', ('HomeGoals', 'mean')]
# Out:
# HomeTeam
# Arsenal                    1.736842
# Aston Villa                1.368421
# Birmingham City            1.000000
# Blackburn Rovers           1.157895
# Blackpool                  1.578947
# Bolton Wanderers           1.789474
# Chelsea                    2.052632
# Everton                    1.631579
# Fulham                     1.578947
# Liverpool                  1.947368
# Manchester City            1.789474
# Manchester United          2.578947
# Newcastle United           2.157895
# Stoke City                 1.631579
# Sunderland                 1.315789
# Tottenham Hotspur          1.578947
# West Bromwich Albion       1.578947
# West Ham United            1.263158
# Wigan Athletic             1.157895
# Wolverhampton Wanderers    1.578947
# Name: (HomeGoals, mean), dtype: float64

# %% [markdown]
# ### > 멀티인덱스 수정
# - 수정 방법
#     1. reset the index level (reset_index 메서드)
#     2. swap the index level
#     3. drop an index level (droplevel 메서드)
# - ✅ Pro Tip
#     - It's best to RESET the index and AVOID multi-index dataframe

# %%
agg_league.head()
# Out:
#                            HomeGoals
#                                  sum      mean
# season    HomeTeam
# 2008/2009 Arsenal                 31  1.631579
#           Aston Villa             27  1.421053
#           Blackburn Rovers        22  1.157895
#           Bolton Wanderers        21  1.105263
#           Chelsea                 33  1.736842

# %%
# droplevel 메서드
agg_league.droplevel(0, axis=1)
# Out:
#                                 sum      mean
# season    HomeTeam
# 2008/2009 Arsenal                31  1.631579
#           Aston Villa            27  1.421053
#           Blackburn Rovers       22  1.157895
#           Bolton Wanderers       21  1.105263
#           Chelsea                33  1.736842
# ...                             ...       ...
# 2015/2016 Swansea City           20  1.052632
#           Tottenham Hotspur      35  1.842105
#           Watford                20  1.052632
#           West Bromwich Albion   20  1.052632
#           West Ham United        34  1.789474
#
# [160 rows x 2 columns]

# %%
(
    agg_league
    .droplevel(0, axis=1)
    .loc[:, 'mean']
)
agg_league = agg_league.droplevel(0, axis=1)

# %%
# swaplevel 메서드
agg_league.swaplevel()
# Out:
#                                 sum      mean
# HomeTeam             season
# Arsenal              2008/2009   31  1.631579
# Aston Villa          2008/2009   27  1.421053
# Blackburn Rovers     2008/2009   22  1.157895
# Bolton Wanderers     2008/2009   21  1.105263
# Chelsea              2008/2009   33  1.736842
# ...                             ...       ...
# Swansea City         2015/2016   20  1.052632
# Tottenham Hotspur    2015/2016   35  1.842105
# Watford              2015/2016   20  1.052632
# West Bromwich Albion 2015/2016   20  1.052632
# West Ham United      2015/2016   34  1.789474
#
# [160 rows x 2 columns]

# %%
agg_league.swaplevel().loc['Arsenal']
# Out:
#            sum      mean
# season
# 2008/2009   31  1.631579
# 2009/2010   48  2.526316
# 2010/2011   33  1.736842
# 2011/2012   39  2.052632
# 2012/2013   47  2.473684
# 2013/2014   36  1.894737
# 2014/2015   41  2.157895
# 2015/2016   31  1.631579

# %%
# reset_index 메서드
agg_league.reset_index()
# Out:
#         season              HomeTeam  sum      mean
# 0    2008/2009               Arsenal   31  1.631579
# 1    2008/2009           Aston Villa   27  1.421053
# 2    2008/2009      Blackburn Rovers   22  1.157895
# 3    2008/2009      Bolton Wanderers   21  1.105263
# 4    2008/2009               Chelsea   33  1.736842
# ..         ...                   ...  ...       ...
# 155  2015/2016          Swansea City   20  1.052632
# 156  2015/2016     Tottenham Hotspur   35  1.842105
# 157  2015/2016               Watford   20  1.052632
# 158  2015/2016  West Bromwich Albion   20  1.052632
# 159  2015/2016       West Ham United   34  1.789474
#
# [160 rows x 4 columns]

# %% [markdown]
# ## 4. Agg 메서드
# ### > Named Aggregation
# - 딕셔너리 전달

# %%
(
    league
    .groupby(['season', 'HomeTeam'], as_index=False)
    .agg({
        'HomeGoals': ['sum', 'mean'],
        'AwayGoals': 'sum'
    })
)
# Out:
#         season              HomeTeam HomeGoals           AwayGoals
#                                            sum      mean       sum
# 0    2008/2009               Arsenal        31  1.631579        16
# 1    2008/2009           Aston Villa        27  1.421053        21
# 2    2008/2009      Blackburn Rovers        22  1.157895        23
# 3    2008/2009      Bolton Wanderers        21  1.105263        21
# 4    2008/2009               Chelsea        33  1.736842        12
# ..         ...                   ...       ...       ...       ...
# 155  2015/2016          Swansea City        20  1.052632        20
# 156  2015/2016     Tottenham Hotspur        35  1.842105        15
# 157  2015/2016               Watford        20  1.052632        19
# 158  2015/2016  West Bromwich Albion        20  1.052632        26
# 159  2015/2016       West Ham United        34  1.789474        26
#
# [160 rows x 5 columns]

# %%
(
    league
    .groupby(['season', 'HomeTeam'], as_index=False)
    .agg(
        HomeGoals_sum=('HomeGoals', 'sum'),
        AwayGoals_sum=('AwayGoals', 'sum')
    )
)
# Out:
#         season              HomeTeam  HomeGoals_sum  AwayGoals_sum
# 0    2008/2009               Arsenal             31             16
# 1    2008/2009           Aston Villa             27             21
# 2    2008/2009      Blackburn Rovers             22             23
# 3    2008/2009      Bolton Wanderers             21             21
# 4    2008/2009               Chelsea             33             12
# ..         ...                   ...            ...            ...
# 155  2015/2016          Swansea City             20             20
# 156  2015/2016     Tottenham Hotspur             35             15
# 157  2015/2016               Watford             20             19
# 158  2015/2016  West Bromwich Albion             20             26
# 159  2015/2016       West Ham United             34             26
#
# [160 rows x 4 columns]

# %% [markdown]
# ## 5. transform 메서드
# perform aggregations without reshaping a dataframe
# ### > ✅ Pro Tip
# - Useful for calculating group-level statistics to perform row-level analysis
# - 그룹별 집계 결과를 각 row data에 추가

# %%
league.head()
# Out:
#      id             league_name     season           HomeTeam  \
# 0  1729  England Premier League  2008/2009  Manchester United
# 1  1730  England Premier League  2008/2009            Arsenal
# 2  1731  England Premier League  2008/2009         Sunderland
# 3  1732  England Premier League  2008/2009    West Ham United
# 4  1733  England Premier League  2008/2009        Aston Villa
#
#                AwayTeam  HomeGoals  AwayGoals
# 0      Newcastle United          1          1
# 1  West Bromwich Albion          1          0
# 2             Liverpool          0          1
# 3        Wigan Athletic          2          1
# 4       Manchester City          4          2

# %%
pm = (
    league
    .assign(
        avg_team_goals=league.groupby('HomeTeam')['HomeGoals'].transform('mean'),
        difference=lambda x: x['HomeGoals'] - x['avg_team_goals']
    )
)
pm
# Out:
#         id             league_name     season              HomeTeam  \
# 0     1729  England Premier League  2008/2009     Manchester United
# 1     1730  England Premier League  2008/2009               Arsenal
# 2     1731  England Premier League  2008/2009            Sunderland
# 3     1732  England Premier League  2008/2009       West Ham United
# 4     1733  England Premier League  2008/2009           Aston Villa
# ...    ...                     ...        ...                   ...
# 3035  4764  England Premier League  2015/2016           Southampton
# 3036  4765  England Premier League  2015/2016          Swansea City
# 3037  4766  England Premier League  2015/2016     Tottenham Hotspur
# 3038  4767  England Premier League  2015/2016               Watford
# 3039  4768  England Premier League  2015/2016  West Bromwich Albion
#
#                   AwayTeam  HomeGoals  AwayGoals  avg_team_goals  difference
# 0         Newcastle United          1          1        2.223684   -1.223684
# 1     West Bromwich Albion          1          0        2.013158   -1.013158
# 2                Liverpool          0          1        1.210526   -1.210526
# 3           Wigan Athletic          2          1        1.466165    0.533835
# 4          Manchester City          4          2        1.177632    2.822368
# ...                    ...        ...        ...             ...         ...
# 3035        Leicester City          2          2        1.763158    0.236842
# 3036            Stoke City          0          1        1.421053   -1.421053
# 3037             Liverpool          0          0        1.677632   -1.677632
# 3038               Arsenal          0          3        1.052632   -1.052632
# 3039            Sunderland          1          0        1.330827   -0.330827
#
# [3040 rows x 9 columns]

# %%
(
    pm
    .groupby(['HomeTeam', 'AwayTeam'])
    .agg({'difference': 'mean'})
    .sort_values('difference')
)
# Out:
#                                              difference
# HomeTeam                AwayTeam
# Chelsea                 Bournemouth           -2.190789
# Southampton             Wigan Athletic        -1.763158
#                         Cardiff City          -1.763158
# Leicester City          Hull City             -1.657895
#                         Manchester City       -1.657895
# ...                                                 ...
# Wolverhampton Wanderers Blackpool              2.912281
# Fulham                  Queens Park Rangers    2.982456
# Everton                 Blackpool              3.302632
# Leicester City          Queens Park Rangers    3.342105
# Arsenal                 Blackpool              3.986842
#
# [932 rows x 1 columns]

# %%
pm.query("HomeTeam == 'Arsenal' and AwayTeam == 'Blackpool'")
# Out:
#        id             league_name     season HomeTeam   AwayTeam  HomeGoals  \
# 870  2599  England Premier League  2010/2011  Arsenal  Blackpool          6
#
#      AwayGoals  avg_team_goals  difference
# 870          0        2.013158    3.986842

# %%
pm.query("AwayTeam == 'Blackpool'")
# Out:
#         id             league_name     season                 HomeTeam  \
# 769   2498  England Premier League  2010/2011           Wigan Athletic
# 795   2524  England Premier League  2010/2011              Aston Villa
# 801   2530  England Premier League  2010/2011          West Ham United
# 828   2557  England Premier League  2010/2011         Bolton Wanderers
# 849   2578  England Premier League  2010/2011               Stoke City
# 870   2599  England Premier League  2010/2011                  Arsenal
# 881   2610  England Premier League  2010/2011               Sunderland
# 894   2623  England Premier League  2010/2011          Manchester City
# 916   2645  England Premier League  2010/2011     West Bromwich Albion
# 943   2672  England Premier League  2010/2011                  Everton
# 966   2695  England Premier League  2010/2011  Wolverhampton Wanderers
# 995   2724  England Premier League  2010/2011         Blackburn Rovers
# 1005  2734  England Premier League  2010/2011                   Fulham
# 1051  2780  England Premier League  2010/2011        Tottenham Hotspur
# 1070  2799  England Premier League  2010/2011        Manchester United
# 1083  2812  England Premier League  2010/2011         Newcastle United
# 1099  2828  England Premier League  2010/2011                  Chelsea
# 1110  2839  England Premier League  2010/2011                Liverpool
# 1135  2864  England Premier League  2010/2011          Birmingham City
#
#        AwayTeam  HomeGoals  AwayGoals  avg_team_goals  difference
# 769   Blackpool          0          4        1.115789   -1.115789
# 795   Blackpool          3          2        1.177632    1.822368
# 801   Blackpool          0          0        1.466165   -1.466165
# 828   Blackpool          2          2        1.368421    0.631579
# 849   Blackpool          0          1        1.342105   -1.342105
# 870   Blackpool          6          0        2.013158    3.986842
# 881   Blackpool          0          2        1.210526   -1.210526
# 894   Blackpool          1          0        2.401316   -1.401316
# 916   Blackpool          3          2        1.330827    1.669173
# 943   Blackpool          5          3        1.697368    3.302632
# 966   Blackpool          4          0        1.087719    2.912281
# 995   Blackpool          2          2        1.289474    0.710526
# 1005  Blackpool          3          0        1.517544    1.482456
# 1051  Blackpool          1          1        1.677632   -0.677632
# 1070  Blackpool          4          2        2.223684    1.776316
# 1083  Blackpool          0          2        1.496241   -1.496241
# 1099  Blackpool          4          0        2.190789    1.809211
# 1110  Blackpool          1          2        1.934211   -0.934211
# 1135  Blackpool          2          0        1.000000    1.000000

# %% [markdown]
# ## 6. 피벗 테이블
# - index (Returns a row index with distinct values from the specified column)
# - columns (Returns a column index with distinct values from the specified column)
# - values (column or columns to perform the aggregations on)
# - aggfunc (Defines the aggregation function/functions to perfrom on the VALUES)
# - margins (Returns row and column totals when True)
#     - specifying margins=True adds row and column totals based on the aggregation

# %%
league.head()
# Out:
#      id             league_name     season           HomeTeam  \
# 0  1729  England Premier League  2008/2009  Manchester United
# 1  1730  England Premier League  2008/2009            Arsenal
# 2  1731  England Premier League  2008/2009         Sunderland
# 3  1732  England Premier League  2008/2009    West Ham United
# 4  1733  England Premier League  2008/2009        Aston Villa
#
#                AwayTeam  HomeGoals  AwayGoals
# 0      Newcastle United          1          1
# 1  West Bromwich Albion          1          0
# 2             Liverpool          0          1
# 3        Wigan Athletic          2          1
# 4       Manchester City          4          2

# %%
(
    league
    .query("HomeTeam in ['Arsenal', 'Chelsea', 'Manchester United']")
    .pivot_table(
        index='HomeTeam',
        columns='season',
        values='HomeGoals',
        aggfunc='sum',
        margins=True
    )
)
# Out:
# season             2008/2009  2009/2010  2010/2011  2011/2012  2012/2013  \
# HomeTeam
# Arsenal                   31         48         33         39         47
# Chelsea                   33         68         39         41         41
# Manchester United         43         52         49         52         45
# All                      107        168        121        132        133
#
# season             2013/2014  2014/2015  2015/2016  All
# HomeTeam
# Arsenal                   36         41         31  306
# Chelsea                   43         36         32  333
# Manchester United         29         41         27  338
# All                      108        118         90  977

# %% [markdown]
# ### > aggfunc
# Multiple Aggregation → Wide Dataframe

# %% [markdown]
# ### > ✅ Pro Tip
# 1. pivot_table? groupby?
#     - Use groupby if don't need to use columns in the pivot_table
#     - groupby 메서드의 named aggregation 기능을 염두에 두자
# 2. pivot_table HEATMAP
#     - Style a Dataframe based on its values to create a heatmap

# %%
pm = (
    league
    .query("HomeTeam in ['Arsenal', 'Chelsea', 'Manchester United']")
    .pivot_table(
        index='HomeTeam',
        columns='season',
        values='HomeGoals',
        aggfunc='mean',
        margins=True
    )
)

pm.style.background_gradient(cmap='RdYlGn', axis=1)
# Out:
# <style type="text/css">
# #T_42426_row0_col0, #T_42426_row0_col7, #T_42426_row1_col7, #T_42426_row2_col7, #T_42426_row3_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_42426_row0_col1, #T_42426_row1_col1, #T_42426_row2_col1, #T_42426_row2_col3, #T_42426_row3_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_42426_row0_col2 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_42426_row0_col3 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_42426_row0_col4 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_42426_row0_col5 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_42426_row0_col6 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_42426_row0_col8 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_42426_row1_col0 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_42426_row1_col2 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_42426_row1_col3, #T_42426_row1_col4 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_42426_row1_col5 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_42426_row1_col6 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_42426_row1_col8 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_42426_row2_col0 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_42426_row2_col2 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_42426_row2_col4 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_42426_row2_col5 {
#   background-color: #cc2627;
#   color: #f1f1f1;
# }
# #T_42426_row2_col6 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_42426_row2_col8 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_42426_row3_col0 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_42426_row3_col2 {
#   background-color: #fede89;
#   color: #000000;
# }
# #T_42426_row3_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_42426_row3_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_42426_row3_col5 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_42426_row3_col6 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_42426_row3_col8 {
#   background-color: #fee491;
#   color: #000000;
# }
# </style>
# <table id="T_42426">
#   <thead>
#     <tr>
#       <th class="index_name level0" >season</th>
#       <th id="T_42426_level0_col0" class="col_heading level0 col0" >2008/2009</th>
#       <th id="T_42426_level0_col1" class="col_heading level0 col1" >2009/2010</th>
#       <th id="T_42426_level0_col2" class="col_heading level0 col2" >2010/2011</th>
#       <th id="T_42426_level0_col3" class="col_heading level0 col3" >2011/2012</th>
#       <th id="T_42426_level0_col4" class="col_heading level0 col4" >2012/2013</th>
#       <th id="T_42426_level0_col5" class="col_heading level0 col5" >2013/2014</th>
#       <th id="T_42426_level0_col6" class="col_heading level0 col6" >2014/2015</th>
#       <th id="T_42426_level0_col7" class="col_heading level0 col7" >2015/2016</th>
#       <th id="T_42426_level0_col8" class="col_heading level0 col8" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >HomeTeam</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42426_level0_row0" class="row_heading level0 row0" >Arsenal</th>
#       <td id="T_42426_row0_col0" class="data row0 col0" >1.631579</td>
#       <td id="T_42426_row0_col1" class="data row0 col1" >2.526316</td>
#       <td id="T_42426_row0_col2" class="data row0 col2" >1.736842</td>
#       <td id="T_42426_row0_col3" class="data row0 col3" >2.052632</td>
#       <td id="T_42426_row0_col4" class="data row0 col4" >2.473684</td>
#       <td id="T_42426_row0_col5" class="data row0 col5" >1.894737</td>
#       <td id="T_42426_row0_col6" class="data row0 col6" >2.157895</td>
#       <td id="T_42426_row0_col7" class="data row0 col7" >1.631579</td>
#       <td id="T_42426_row0_col8" class="data row0 col8" >2.013158</td>
#     </tr>
#     <tr>
#       <th id="T_42426_level0_row1" class="row_heading level0 row1" >Chelsea</th>
#       <td id="T_42426_row1_col0" class="data row1 col0" >1.736842</td>
#       <td id="T_42426_row1_col1" class="data row1 col1" >3.578947</td>
#       <td id="T_42426_row1_col2" class="data row1 col2" >2.052632</td>
#       <td id="T_42426_row1_col3" class="data row1 col3" >2.157895</td>
#       <td id="T_42426_row1_col4" class="data row1 col4" >2.157895</td>
#       <td id="T_42426_row1_col5" class="data row1 col5" >2.263158</td>
#       <td id="T_42426_row1_col6" class="data row1 col6" >1.894737</td>
#       <td id="T_42426_row1_col7" class="data row1 col7" >1.684211</td>
#       <td id="T_42426_row1_col8" class="data row1 col8" >2.190789</td>
#     </tr>
#     <tr>
#       <th id="T_42426_level0_row2" class="row_heading level0 row2" >Manchester United</th>
#       <td id="T_42426_row2_col0" class="data row2 col0" >2.263158</td>
#       <td id="T_42426_row2_col1" class="data row2 col1" >2.736842</td>
#       <td id="T_42426_row2_col2" class="data row2 col2" >2.578947</td>
#       <td id="T_42426_row2_col3" class="data row2 col3" >2.736842</td>
#       <td id="T_42426_row2_col4" class="data row2 col4" >2.368421</td>
#       <td id="T_42426_row2_col5" class="data row2 col5" >1.526316</td>
#       <td id="T_42426_row2_col6" class="data row2 col6" >2.157895</td>
#       <td id="T_42426_row2_col7" class="data row2 col7" >1.421053</td>
#       <td id="T_42426_row2_col8" class="data row2 col8" >2.223684</td>
#     </tr>
#     <tr>
#       <th id="T_42426_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_42426_row3_col0" class="data row3 col0" >1.877193</td>
#       <td id="T_42426_row3_col1" class="data row3 col1" >2.947368</td>
#       <td id="T_42426_row3_col2" class="data row3 col2" >2.122807</td>
#       <td id="T_42426_row3_col3" class="data row3 col3" >2.315789</td>
#       <td id="T_42426_row3_col4" class="data row3 col4" >2.333333</td>
#       <td id="T_42426_row3_col5" class="data row3 col5" >1.894737</td>
#       <td id="T_42426_row3_col6" class="data row3 col6" >2.070175</td>
#       <td id="T_42426_row3_col7" class="data row3 col7" >1.578947</td>
#       <td id="T_42426_row3_col8" class="data row3 col8" >2.142544</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### > melt 메서드
# - Unpivot a dataframe
# - from WIDE to LONG dataframe
# - args
#     1. id_vars
#     2. value_vars
#     3. var_name & value_name

# %%
pm.head()
# Out:
# season             2008/2009  2009/2010  2010/2011  2011/2012  2012/2013  \
# HomeTeam
# Arsenal             1.631579   2.526316   1.736842   2.052632   2.473684
# Chelsea             1.736842   3.578947   2.052632   2.157895   2.157895
# Manchester United   2.263158   2.736842   2.578947   2.736842   2.368421
# All                 1.877193   2.947368   2.122807   2.315789   2.333333
#
# season             2013/2014  2014/2015  2015/2016       All
# HomeTeam
# Arsenal             1.894737   2.157895   1.631579  2.013158
# Chelsea             2.263158   1.894737   1.684211  2.190789
# Manchester United   1.526316   2.157895   1.421053  2.223684
# All                 1.894737   2.070175   1.578947  2.142544

# %%
(
    pm
    .reset_index()
    .melt(
        id_vars='HomeTeam',
        value_vars=['2008/2009', '2009/2010', '2010/2011'],
        value_name='avg_goals'
    )
)
# Out:
#              HomeTeam     season  avg_goals
# 0             Arsenal  2008/2009   1.631579
# 1             Chelsea  2008/2009   1.736842
# 2   Manchester United  2008/2009   2.263158
# 3                 All  2008/2009   1.877193
# 4             Arsenal  2009/2010   2.526316
# 5             Chelsea  2009/2010   3.578947
# 6   Manchester United  2009/2010   2.736842
# 7                 All  2009/2010   2.947368
# 8             Arsenal  2010/2011   1.736842
# 9             Chelsea  2010/2011   2.052632
# 10  Manchester United  2010/2011   2.578947
# 11                All  2010/2011   2.122807

# %% [markdown]
# # 🚩 데이터프레임 집계 정리
# 1. Use groupby 메서드 to aggregate a Dataframe by specific columns
# 2. Work with multi-index Dataframe and reset them
#     - Multi-index Dataframes are created by default when grouping by more than one column
#     - It is worth knowing how to access multi-index Dataframes
# 3. Use agg 메서드 to specify multiple aggregation functions when grouping
#     - Named aggregation allow you to set intuitive column names and prevent multi-index columns
# 4. pivot_table/melt 메서드 → pivot, unpivot Dataframe
